# %% [markdown]
# ## Day04 - 0429 과제 수행 및 강사님 풀이

# %% [markdown]
# Task1_0429. input_str을 아래와 같이 단어로 분리하여 출력하세요
# input_str="Hello, world! How are you today? I am fine. Thank you!"
#
# ['Hello', 'world', ' How', 'are', 'you', 'today', 'I', 'am', 'fine', Thank', 'you', '']

# %%
#  모르겠음

# %% [markdown]
# Task2_0429. 십진수 122를 2진수, 8진수, 16진수로 변경하여 출력하세요.

# %%
a=122
# 2진수 변환
print(bin(122))
# 8진수 변환
print(oct(122))
# 16진수 변환
print(hex(122))
# Out:
# 0b1111010
# 0o172
# 0x7a

# %% [markdown]
# Task3_0429. 두 수의 곱셈 결과를 계산하고, 그 결과에 10을 더하세요.

# %%
num1=int(input("첫번째 숫자를 입력하세요 : "))
num2=int(input("두번째 숫자를 입력하세요 : "))
result=(num1*num2)+10
print(result)
# Out:
# 첫번째 숫자를 입력하세요 : 10
# 두번째 숫자를 입력하세요 : 20
# 210

# %% [markdown]
# Task4_0429. 주어진 리스트에서 두 번째 요소를 삭제하고, 마지막에 새로운 요소 'Python'을 추가하세요.
#
# 리스트: ['Java', 'C', 'JavaScript']

# %%
list1=['Java', 'C', 'JavaScript']

list1.pop(1)
list1.append('JavaScript')
print(list1)
# Out:
# ['Java', 'JavaScript', 'JavaScript']

# %% [markdown]
# Task5_0429. 주어진 문자열에서 처음 세 글자와 마지막 세 글자를 연결하여 새로운 문자열을 만드세요.
#
# 문자열: 'Incredible'

# %%
str1='Incredible'
str2=str1[:3]+str1[-3:]

print(str2)
# Out:
# Incble

# %% [markdown]
# Task6_0429. 사용자의 이름과 이메일을 딕셔너리로 저장하고, 이름을 입력받아 해당하는 이메일을 출력하세요.
#
# 사용자 정보: 이름 - 'Alice', 이메일 - 'alice@example.com'

# %%
dict1={'Alice':'alice@example.com'}
find1=input("찾으실 이름을 입력하세요 : ")
print(dict1[find1])
# Out:
# 찾으실 이름을 입력하세요 : Alice
# alice@example.com

# %% [markdown]
# Task7_0429. 주어진 두 튜플에서 공통 요소만을 찾아 집합으로 만드세요.
#
# 튜플: (1, 2, 3, 4, 5)와 (4, 5, 6, 7, 8)

# %%
tup1=(1, 2, 3, 4, 5)
tup2=(4, 5, 6, 7, 8)

tup1=set(tup1)
tup2=set(tup2)
result=tup1&tup2
print(f"두 튜플의 공통 요소는 : {result}")
# Out:
# 두 튜플의 공통 요소는 : {4, 5}

# %% [markdown]
# Task8_Challenge_0429. 다음 요구 사항을 충족하는 프로그램을 작성하세요:
#
# - 사용자로부터 이름, 나이, 좋아하는 색상을 입력받습니다.
# - 입력받은 정보를 딕셔너리로 저장하고, 모든 사용자 정보를 리스트에 저장합니다.
# - 이름이 'John'인 사용자의 정보만 출력하세요.
# - 전체 사용자의 평균 나이를 계산하고 출력하세요.
#
# 1. 사용자 데이터:
# - 이름: John
# - 나이: 28
# - 좋아하는 색상: Blue
# 2. 사용자 데이터:
# - 이름: Alice
# - 나이: 24
# - 좋아하는 색상: Red
# 3. 사용자 데이터:
# - 이름: Maria
# - 나이: 32
# - 좋아하는 색상: Green

# %%
# 1. 데이터 수집 및 저장
# for문 사용해서 각 사용자 데이터 수집
# 수집된 데이터는 딕셔너리 폼으로 저장 - 사용자 이름을 key로, 나이와 색상을 튜플 형태로 묶어야 함

# data1={'John': [28,'blue'], 'Alice':[24,'red'], 'Maria':[32,'green']}
data1={}
for i in range(3):
    name=str(input("이름을 입력하세요 : "))
    age=int(input("나이를 입력하세요 : "))
    color=str(input("좋아하는 색깔을 입력하세요 : "))
    data1[name]=[age,color]
print(data1)
print("\n")
# 2. John의 정보만 출력
print(f"John 정보\n나이: {data1['John'][0]}\n좋아하는 색깔: {data1['John'][1]}")

# 3. 사용자 평균 나이 계산
print("\n")
age=[value[0] for value in data1.values()]
# print(age)
total=0
average=0
for i in age:
    total+=i
    average=total/len(age)
print(f"평균 나이는 {average}입니다.")
# Out:
# 이름을 입력하세요 : John
# 나이를 입력하세요 : 28
# 좋아하는 색깔을 입력하세요 : Blue
# 이름을 입력하세요 : Alice
# 나이를 입력하세요 : 24
# 좋아하는 색깔을 입력하세요 : Red
# 이름을 입력하세요 : Maria
# 나이를 입력하세요 : 32
# 좋아하는 색깔을 입력하세요 : Green
# {'John': [28, 'Blue'], 'Alice': [24, 'Red'], 'Maria': [32, 'Green']}
#
#
# John 정보
# 나이: 28
# 좋아하는 색깔: Blue
#
#
# 평균 나이는 28.0입니다.

# %%
# 아래 정보에서 좋아하는 색상만 추출한다면?
data1={'John': [28,'blue'], 'Alice':[24,'red'], 'Maria':[32,'green']}

color=[]
for value in data1.values():
    color.append(value[1])
print(color)
# Out:
# ['blue', 'red', 'green']
