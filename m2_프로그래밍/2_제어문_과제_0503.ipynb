# %% [markdown]
# Q. 여러개 음식을 동시에 주문할 수 있는 주문 시스템을 작성하세요. (구조 지향)

# %% [markdown]
# ###### 1번째 시도 실패한 코드:

# %%
# # 여러개 음식을 동시에 주문할 수 있는 주문 시스템을 작성하세요. (구조 지향)

# # 1. 주문판을 보여주는 함수
# # 2. 주문 접수를 받는 함수
# # 3. 추가 주문 여부를 확인
# # 4. 추가 주문 선택 시 2~3 다시 실행
# # 5. 추가 주문 없을 시 가격 안내


# # 1. 주문판 출력
# def display_menu():
#     print(
# '''
# KITA 식당에 오신 것을 환영합니다

# ========================================

#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원

#     세트 주문시 : 3000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)

# ========================================
# '''
# )

# # 2. 주문 접수를 받는 함수
# def order():
# # a. 메뉴 선택하세요
#     menu={1:['불고기 비빔밥', 12000], 2:['야채 비빔밥', 8000], 3:['전주 비빔밥', 10000]}
#     set_price=3000
#     global current_order
#     menu_select=int(input("원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> "))
#     current_order=menu[menu_select]
#     print(f"선택하신 메뉴는 {current_order[0]}입니다.")

# # b. 세트로 하시겠습니까?
#     menu_set=input("세트로 하시겠습니까? y,n >>> ").lower()
#     global current_price
#     if menu_set=='y':
#         current_price=current_order[1]+set_price
#         print(f"세트를 선택하셨습니다. 금액은 {current_price}원 입니다.")
#     else:
#         print(f"단품을 선택하셨습니다. 금액은 {current_order[1]}원 입니다.")

# # 3. 추가 주문 여부를 확인
# def add_order():
#     final_order=[]
#     final_price=0
#     menu_add=input("메뉴를 추가하시겠습니까? y,n >>> ")
#     if menu_add=='y':
#         order()
#         final_order+=current_order
#         final_price+=current_price
#         print(f"최종적으로 선택하신 메뉴는 : {final_order}입니다.")
#     else:
#         final_order=current_order
#         print(f"최종적으로 선택하신 메뉴는 : {final_order}입니다.")

# # 이 모든 것을 한 번에 해결해줄 최종보스:

# def main():
#     while True:
#         display_menu()
#         order()
#         add_order()
#         reset_order=input("다시 주문하시겠습니까? y,n >>> ")
#         if reset_order=='n':
#             break
#     print("주문해주셔서 감사합니다. 잠시만 기다려주세요.")

# if __name__ == "__main__":
#     main()

# %% [markdown]
# ##### 2번째 시도 실패한 코드

# %%
# # 여러개 음식을 동시에 주문할 수 있는 주문 시스템을 작성하세요. (구조 지향)

# # 1. 주문판을 보여주는 함수
# # 2. 주문 접수를 받는 함수
# # 3. 추가 주문 여부를 확인
# # 4. 추가 주문 선택 시 2~3 다시 실행
# # 5. 추가 주문 없을 시 가격 안내


# # 1. 주문판 출력
# def display_menu():
#     print(
# '''
# KITA 식당에 오신 것을 환영합니다

# ========================================

#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원

#     세트 주문시 : 3000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)

# ========================================
# '''
# )

# # 2. 주문 접수를 받는 함수
# def order():
# # a. 메뉴 선택하세요
#     menu={1:['불고기 비빔밥', 12000], 2:['야채 비빔밥', 8000], 3:['전주 비빔밥', 10000]}
#     set_price=3000
#     global current_order
#     menu_select=int(input("원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> "))
#     current_order=menu[menu_select]
#     print(f"선택하신 메뉴는 {current_order[0]}입니다.")

# # b. 세트로 하시겠습니까?
#     menu_set=input("세트로 하시겠습니까? y,n >>> ").lower()
#     global current_price
#     if menu_set=='y':
#         current_price=current_order[1]+set_price
#         print(f"세트를 선택하셨습니다. 금액은 {current_price}원 입니다.")
#     else:
#         current_price=current_order[1]
#         print(f"단품을 선택하셨습니다. 금액은 {current_price}원 입니다.")

# # 3. 추가 주문 여부를 확인
# def add_order():
#     final_order=[]
#     final_price=0
#     while True:
#         menu_add=input("메뉴를 추가하시겠습니까? y,n >>> ").lower()
#         if menu_add=='y':
#             order()
#             final_order.append({'메뉴': current_order[0], '가격':current_price}) # order()에서 입력된 다중의 current order의 cumulative 리스트를 원하는데 어떻게 해야하는지 모르겠네
#             final_price+=current_price
#             print(f"현재까지 선택하신 메뉴는 : {final_order}입니다.")
#         else:
#             print(f"최종적으로 선택하신 메뉴는 : {final_order}입니다.")
#             print(f"최종 가격은 {final_price}원 입니다.")
#             break

# # 이 모든 것을 한 번에 해결해줄 최종보스:

# def main():
#     while True:
#         display_menu()
#         order()
#         add_order()
#         reset_order=input("다시 주문하시겠습니까? y,n >>> ")
#         if reset_order=='n':
#             break
#     print("주문해주셔서 감사합니다. 잠시만 기다려주세요.")

# if __name__ == "__main__":
#     main()

# %% [markdown]
# ##### add_order() 함수 부분이 풀리지 않아서 GPT의 솔루션 확인함

# %%
# GPT가 수정해준 코드 :
# 1. 주문판 출력
def display_menu():
    print(
'''
KITA 식당에 오신 것을 환영합니다

========================================

          - 메  뉴 -
    1. 불고기 비빔밥 : 12,000원
    2. 야채 비빔밥 : 8,000원
    3. 전주 비빔밥 : 10,000원

    세트 주문시 : 3000원 추가
    (세트는 밥과 반찬이 추가됩니다.)

========================================
'''
)

# 2. 주문 접수를 받는 함수
def order():
    menu = {1: ['불고기 비빔밥', 12000], 2: ['야채 비빔밥', 8000], 3: ['전주 비빔밥', 10000]}
    set_price = 3000
    global current_order
    global current_price
    menu_select = int(input("원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> "))
    current_order = menu[menu_select]
    print(f"선택하신 메뉴는 {current_order[0]}입니다.")

    # 세트 여부 확인
    menu_set = input("세트로 하시겠습니까? y,n >>> ").lower()
    if menu_set == 'y':
        current_price = current_order[1] + set_price
        print(f"세트를 선택하셨습니다. 금액은 {current_price}원 입니다.")
    else:
        current_price = current_order[1]
        print(f"단품을 선택하셨습니다. 금액은 {current_price}원 입니다.")

# 3. 추가 주문 여부를 확인
def add_order(final_order, final_price):
    while True:
        menu_add = input("메뉴를 추가하시겠습니까? y,n >>> ").lower()
        if menu_add == 'y':
            order()  # 주문 추가
            final_order.append({'메뉴': current_order[0], '가격': current_price})  # 주문 내역에 추가
            final_price += current_price  # 총 가격 업데이트
            print(f"현재까지 선택하신 메뉴는 : {final_order}입니다.")
        else:
            print(f"최종적으로 선택하신 메뉴는 : {final_order}입니다.")
            print(f"최종 가격은 {final_price}원 입니다.")
            break

# 이 모든 것을 한 번에 해결해줄 최종보스:
def main():
    final_order = []  # 주문 내역을 저장할 리스트
    final_price = 0  # 총 가격 초기화

    while True:
        display_menu()
        order()
        final_order.append({'메뉴': current_order[0], '가격': current_price})  # 초기 주문 내역 저장
        final_price += current_price  # 초기 가격 계산
        add_order(final_order, final_price)  # 추가 주문 확인
        reset_order = input("다시 주문하시겠습니까? y,n >>> ")
        if reset_order.lower() == 'n':
            break
    print("주문해주셔서 감사합니다. 잠시만 기다려주세요.")

if __name__ == "__main__":
    main()
# Out:
# KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
#
# 원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> 3
# 선택하신 메뉴는 전주 비빔밥입니다.
# 세트로 하시겠습니까? y,n >>> ㅛ
# 단품을 선택하셨습니다. 금액은 10000원 입니다.
# 메뉴를 추가하시겠습니까? y,n >>> y
# 원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> 2
# 선택하신 메뉴는 야채 비빔밥입니다.
# 세트로 하시겠습니까? y,n >>> y
# 세트를 선택하셨습니다. 금액은 11000원 입니다.
# 현재까지 선택하신 메뉴는 : [{'메뉴': '전주 비빔밥', '가격': 10000}, {'메뉴': '야채 비빔밥', '가격': 11000}]입니다.
# 메뉴를 추가하시겠습니까? y,n >>> n
# 최종적으로 선택하신 메뉴는 : [{'메뉴': '전주 비빔밥', '가격': 10000}, {'메뉴': '야채 비빔밥', '가격': 11000}]입니다.
# 최종 가격은 21000원 입니다.
# 다시 주문하시겠습니까? y,n >>> n
# 주문해주셔서 감사합니다. 잠시만 기다려주세요.

# %% [markdown]
# ##### GPT 수정 사항 확인하여 업데이트한 최종본

# %%
# GPT 수정 사항 확인 후 업데이트한 최종본
# 여러개 음식을 동시에 주문할 수 있는 주문 시스템을 작성하세요. (구조 지향)

# 1. 주문판을 보여주는 함수
# 2. 주문 접수를 받는 함수
# 3. 추가 주문 여부를 확인
# 4. 추가 주문 선택 시 2~3 다시 실행
# 5. 추가 주문 없을 시 가격 안내


# 1. 주문판 출력
def display_menu():
    print(
'''
KITA 식당에 오신 것을 환영합니다

========================================

          - 메  뉴 -
    1. 불고기 비빔밥 : 12,000원
    2. 야채 비빔밥 : 8,000원
    3. 전주 비빔밥 : 10,000원

    세트 주문시 : 3000원 추가
    (세트는 밥과 반찬이 추가됩니다.)

========================================
'''
)

# 2. 주문 접수를 받는 함수
def order():
# a. 메뉴 선택하세요
    menu={1:['불고기 비빔밥', 12000], 2:['야채 비빔밥', 8000], 3:['전주 비빔밥', 10000]}
    set_price=3000
    global current_order
    menu_select=int(input("원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> "))
    current_order=menu[menu_select]
    print(f"선택하신 메뉴는 {current_order[0]}입니다.")

# b. 세트로 하시겠습니까?
    menu_set=input("세트로 하시겠습니까? y,n >>> ").lower()
    global current_price
    if menu_set=='y':
        current_price=current_order[1]+set_price
        print(f"세트를 선택하셨습니다. 금액은 {current_price}원 입니다.")
    else:
        current_price=current_order[1]
        print(f"단품을 선택하셨습니다. 금액은 {current_price}원 입니다.")

# 3. 추가 주문 여부를 확인
def add_order(final_order, final_price):
    while True:
        menu_add=input("메뉴를 추가하시겠습니까? y,n >>> ").lower()
        if menu_add=='y':
            order()
            final_order.append({'메뉴': current_order[0], '가격':current_price}) # order()에서 입력된 다중의 current order의 cumulative 리스트를 원하는데 어떻게 해야하는지 모르겠네
            final_price+=current_price
            print(f"현재까지 선택하신 메뉴는 : {final_order}입니다.")
        else:
            print(f"최종적으로 선택하신 메뉴는 : {final_order}입니다.")
            print(f"최종 가격은 {final_price}원 입니다.")
            break

# 이 모든 것을 한 번에 해결해줄 최종보스:

def main():
    final_order=[]
    final_price=0
    while True:
        display_menu()
        order()
        final_order.append({'메뉴': current_order[0], '가격': current_price})  # 초기 주문 내역 저장
        final_price += current_price  # 초기 가격 계산
        add_order(final_order, final_price)
        reset_order=input("다시 주문하시겠습니까? y,n >>> ")
        if reset_order.lower()=='n':
            break
    print("주문해주셔서 감사합니다. 잠시만 기다려주세요.")

if __name__ == "__main__":
    main()
# Out:
# KITA 식당에 오신 것을 환영합니다
#
# ...
#
#           - 메  뉴 -
#     1. 불고기 비빔밥 : 12,000원
#     2. 야채 비빔밥 : 8,000원
#     3. 전주 비빔밥 : 10,000원
#
#     세트 주문시 : 3000원 추가
#     (세트는 밥과 반찬이 추가됩니다.)
#
# ...
#
# 원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> 3
# 선택하신 메뉴는 전주 비빔밥입니다.
# 세트로 하시겠습니까? y,n >>> y
# 세트를 선택하셨습니다. 금액은 13000원 입니다.
# 메뉴를 추가하시겠습니까? y,n >>> y
# 원하시는 메뉴의 번호를 선택하세요. 1,2,3 >>> 2
# 선택하신 메뉴는 야채 비빔밥입니다.
# 세트로 하시겠습니까? y,n >>> y
# 세트를 선택하셨습니다. 금액은 11000원 입니다.
# 현재까지 선택하신 메뉴는 : [{'메뉴': '전주 비빔밥', '가격': 13000}, {'메뉴': '야채 비빔밥', '가격': 11000}]입니다.
# 메뉴를 추가하시겠습니까? y,n >>> n
# 최종적으로 선택하신 메뉴는 : [{'메뉴': '전주 비빔밥', '가격': 13000}, {'메뉴': '야채 비빔밥', '가격': 11000}]입니다.
# 최종 가격은 24000원 입니다.
# 다시 주문하시겠습니까? y,n >>> n
# 주문해주셔서 감사합니다. 잠시만 기다려주세요.

# %% [markdown]
# #### Task 1_0503 강사님 풀이
# [시나리오]
# 1. 시작 인터페이스:
# - 시스템 시작 시, 사용자에게 주문 시작 여부를 질문 (y 또는 n으로 응답).
# - y 선택 시 주문 프로세스 시작.
# - n 선택 시 시스템 종료 및 "감사합니다." 메시지 표시.
# 2. 메뉴 표시:
# - 주문 프로세스 시작 시, 현재 메뉴 항목과 가격 표시.
# - 각 메뉴 옆에는 선택 번호 제공 (예: 1, 2, 3).
# - 세트 주문 시 추가 비용 안내 (3000원 추가).
# 3. 주문 입력:
# - 메뉴 선택 입력 요청.
# - 메뉴 번호 입력 후 세트 주문 여부 질문 (y는 세트, n은 일반).
# - 주문 수량 질문 후, 주문 장바구니에 추가.
# - 주문이 추가된 후 해당 내용 표시.
# 4. 주문 취소:
# - 잘못 주문했거나 주문 취소 시 0 입력.
# - 주문 취소 시 "모든 주문이 취소되었습니다." 메시지 표시.
# 5. 주문 요약 및 결제:
# - 주문 완료하려면 5 입력.
# - 주문 내역 및 총 금액 요약 표시.
# - 결제 금액 안내 및 결제 진행 요청.
# - 결제 완료 후 "총 금액은 XXX원이 결제되었습니다. 감사합니다." 메시지 표시 및 주문 초기화.
# 6. 반복 주문 가능:
# - 결제 후 추가 주문 진행 가능.
# - 언제든지 n 입력하여 주문 프로세스 종료 및 시스템 빠져나올 수 있음.

# %% [markdown]
# [ 함수 구성 및 역할 ]
# 1. display_menu()
# - 역할: 사용자에게 메뉴 선택지를 표시.
# - 세부 기능: 메뉴 아이템과 각각의 가격, 세트 주문 시 추가 비용을 표시.
# - 시나리오 연결: 사용자가 주문 프로세스를 시작할 때, 어떤 메뉴를 선택할 수 있는지 표시.
# 2. display_order_summary()
# - 역할: 현재 주문 상태를 요약하여 표시.
# - 세부 기능: 선택된 메뉴 항목, 수량, 세트 여부, 각 항목의 가격과 총 주문 금액을 계산하여 표시.
# - 시나리오 연결: 주문을 마친 후, 사용자가 자신의 주문 내역을 확인하고 최종 결제하기 전에 전체 주문 내용 검토.
# 3. add_order(menu_id, is_set)
# - 역할: 사용자의 메뉴 선택을 주문 목록에 추가.
# - 세부 기능: 메뉴 ID와 세트 여부에 따라 주문을 추가하고, 추가된 주문 정보를 사용자에게 전달.
# - 시나리오 연결: 사용자가 메뉴를 선택하고 주문 수량을 입력할 때, 해당 주문을 시스템에 추가 및 확인.
# 4. process_order()
# - 역할: 주문 프로세스의 메인 컨트롤러.
# - 세부 기능: 사용자의 입력을 받아 메뉴 선택, 주문, 주문 취소, 결제를 처리하고, 프로세스의 시작과 종료를 관리.
# - 시나리오 연결: 전체 주문 프로세스를 실행하고, 사용자의 각 선택에 따라 적절한 행동을 지시하며, 필요에 따라 다른 함수들을 호출.
#
# [ 시나리오의 흐름과 함수 연결 ]
# 1. 시작: 사용자가 주문을 시작하겠다고 응답하면 (y 입력), display_menu() 함수가 호출되어 사용 가능한 메뉴를 표시.
# 2. 메뉴 선택: 사용자가 메뉴 번호를 입력하고, 세트 여부를 선택하면 add_order() 함수가 호출되어 주문을 추가.
# 3. 주문 확인: 주문을 추가할 때마다 display_order_summary() 함수가 호출되어 현재까지의 주문 상태를 확인.
# 4. 주문 수정 또는 결제: 사용자가 주문을 취소하거나 변경할 수 있고, 최종적으로 결제를 원할 때 process_order() 함수 내에서 결제를 진행.
# 4. 종료: 주문 결제가 완료되면, 사용자가 추가 주문을 원하지 않을 경우 (n 입력), 시스템이 종료.
#
# 이러한 구조화된 접근 방식은 코드의 각 부분이 시나리오의 어떤 단계와 연결되는지 명확하게 정의하며, 시스템의 유지 관리와 확장성을 개선.

# %%
# 강사님 풀이 (코드)
# 메뉴 아이템과 가격
menu_items={
    '1': ('불고기 비빔밥', 12000),
    '2': ('야채 비빔밥', 8000),
    '3': ('전주 비빔밥', 10000)
}
set_price=3000
orders={}
price_total=0

def display_menu():
    print("\n♣♣♣ KITA 식당에 오신 것을 환영합니다 ♣♣♣")
    print("========================================")
    print("           - 메뉴 -")
    for key, (name, price) in menu_items.items():
        print(f"  {key}. {name} : {price}원")
    print("\n  세트 주문시 : 3000원 추가 (세트는 밥과 반찬이 추가됩니다.)")
    print("========================================")

def display_order_summary():
    global price_total # 전역 변수 price_total  사용 선언
    print("\n■장바구니")
    price_total=0
    for key, (name, price) in menu_items.items():
        count=orders.get((key, False),0)
        count_set=orders.get((key,True),0)
        print(f" {name} {count}개: {count*price}원")
        print(f" {name} 세트 {count_set}개 : {count_set*(price+set_price)}원")
        price_total+=(count*price)+(count_set*(price+set_price))
    print(f"총 금액 {price_total}원\n")

def add_order(menu_id, is_set):
    item_name, item_price=menu_items[menu_id]
    if is_set:
        item_price+=set_price
    num=input(f"\n● {item_name}{'세트' if is_set else ''} 몇 개 주문 하시겠습니까?\n")
    if num.isdigit() and int(num)>0:
        orders[(menu_id, is_set)]=orders.get((menu_id, is_set),0)+int(num) # orders는 {(menu_id, is_set):개수}
        # orders.get((menu_id, is_set),0)에서 0의 의미는:
        # orders 딕셔너리에서 (menu_id, is_set) 키에 해당하는 값을 찾는데, 만약 해당하는 키가 없다면 기본값으로 0을 반환
        print(f"\n{item_name}{'세트' if is_set else ''}{num}개가 장바구니에 담겼습니다.\n")
    else:
        print('★양수만 입력하세요.★')

def process_order():
    while True:
        msg=input("●주문을 하시겠습니까? (y 또는 n) >> ").strip().lower()
        if msg=='y':
            while True:
                display_menu()
                display_order_summary()
                choice=input("●주문할 메뉴를 골라주세요. (불고기 비빔밥: 1, 야채 비빔밥: 2, 전주 비빔밥: 3, 전체 취소: 0, 결재: 5) >> ").strip().lower()
                if choice in menu_items:
                    set_choice=input("●\n3000원을 추가해 세트로 주문하시겠습니까? (일반주문시: n, 세트주문시: y)\n").strip().lower()
                    if set_choice in ['y', 'n']:
                        add_order(choice, set_choice=='y') # set_choice는 bool 값으로 들어감
                        # 세트라면 add_order 함수의 매게변수로 choice, set_choice 가 들어가고 주문이 추가됨
                        # add_order의 menu_id=choice, is_set = set_choice
                    else:
                        print('★올바른 선택을 입력하세요 (y 또는 n)★')
                elif choice=='0':
                    orders.clear()
                    print("\n모든 주문이 취소되었습니다.")
                elif choice=='5':
                    if price_total>0:
                        print(f"\n●주문하려면 결제해주세요. 결제 금액은 {price_total}원 입니다\n")
                        input("결제를 완료하려면 아무 키나 누르세요.") # 사용자가 결제를 확인할 수 있도록 입력 대기
                        print(f"\n총 금액 {price_total}원이 결제되었습니다. 감사합니다.")
                        orders.clear()
                        break
                    else:
                        print('★메뉴를 고르고 주문해주세요!★')
                else:
                     print('★메뉴의 지정된 숫자로 입력하세요★')
        else:
            print('감사합니다.')
            break
if __name__=='__main__':
    process_order()
# Out:
# ●주문을 하시겠습니까? (y 또는 n) >> y
#
# ♣♣♣ KITA 식당에 오신 것을 환영합니다 ♣♣♣
# ...
#            - 메뉴 -
#   1. 불고기 비빔밥 : 12000원
#   2. 야채 비빔밥 : 8000원
#   3. 전주 비빔밥 : 10000원
#
#   세트 주문시 : 3000원 추가 (세트는 밥과 반찬이 추가됩니다.)
# ...
#
# ■장바구니
#  불고기 비빔밥 0개: 0원
#  불고기 비빔밥 세트 0개 : 0원
#  야채 비빔밥 0개: 0원
#  야채 비빔밥 세트 0개 : 0원
#  전주 비빔밥 0개: 0원
#  전주 비빔밥 세트 0개 : 0원
# 총 금액 0원
#
# ●주문할 메뉴를 골라주세요. (불고기 비빔밥: 1, 야채 비빔밥: 2, 전주 비빔밥: 3, 전체 취소: 0, 결재: 5) >> 1
# ●
# 3000원을 추가해 세트로 주문하시겠습니까? (일반주문시: n, 세트주문시: y)
# y
#
# ● 불고기 비빔밥세트 몇 개 주문 하시겠습니까?
# 1
#
# 불고기 비빔밥세트1개가 장바구니에 담겼습니다.
#
#
# ♣♣♣ KITA 식당에 오신 것을 환영합니다 ♣♣♣
# ...
#            - 메뉴 -
#   1. 불고기 비빔밥 : 12000원
#   2. 야채 비빔밥 : 8000원
#   3. 전주 비빔밥 : 10000원
#
#   세트 주문시 : 3000원 추가 (세트는 밥과 반찬이 추가됩니다.)
# ...
#
# ■장바구니
#  불고기 비빔밥 0개: 0원
#  불고기 비빔밥 세트 1개 : 15000원
#  야채 비빔밥 0개: 0원
#  야채 비빔밥 세트 0개 : 0원
#  전주 비빔밥 0개: 0원
#  전주 비빔밥 세트 0개 : 0원
# 총 금액 15000원
#
# ●주문할 메뉴를 골라주세요. (불고기 비빔밥: 1, 야채 비빔밥: 2, 전주 비빔밥: 3, 전체 취소: 0, 결재: 5) >> 2
# ●
# 3000원을 추가해 세트로 주문하시겠습니까? (일반주문시: n, 세트주문시: y)
# n
#
# ...
