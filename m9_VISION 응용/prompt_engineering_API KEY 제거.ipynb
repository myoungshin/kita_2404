# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.

# %%
# !pip install -q openai # -q : quiet 모드
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00

# %%
from openai import OpenAI
client=OpenAI(api_key="")


completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content" : "당신은 AI 모델 개발자이다."},
        {"role": "user", "content" : "LLM에 대해 설명해줘."}
    ]
)

print(completion.choices[0].message.content)
# Out:
# LLM은 "Large Language Model"의 약자로, 대규모 언어 모델을 의미합니다. 이러한 모델은 자연어 처리(NLP) 작업을 수행하기 위해 설계되었으며, 대량의 텍스트 데이터를 기반으로 학습하여 언어의 패턴과 구조를 이해합니다.
#
# ### LLM의 주요 특징:
#
# 1. **대규모 데이터**: LLM은 인터넷, 책, 기사 등에서 수집된 방대한 양의 텍스트 데이터로 학습됩니다. 이로 인해 다양한 주제에 대한 지식과 언어의 뉘앙스를 이해하게 됩니다.
#
# 2. **딥 러닝 기술**: LLM은 신경망 아키텍처를 사용하여 입력된 문장을 처리하고, 이를 바탕으로 다음 단어를 예측하거나, 질문에 답하는 등의 작업을 수행합니다. 주로 Transformer 아키텍처에 기반하고 있습니다.
#
# 3. **맥락 이해**: LLM은 문맥을 이해하고, 주어진 텍스트의 흐름에 따라 적절한 응답이나 출력을 생성할 수 있습니다. 이는 대화형 AI, 텍스트 생성, 번역, 요약 등 다양한 분야에서 유용하게 사용됩니다.
#
# 4. **전이 학습**: LLM은 기본적인 언어 처리 작업을 위해 사전 훈련(pre-training)을 거치고, 이후 특정 작업에 맞게 미세 조정(fine-tuning)됩니다. 이를 통해 다양한 NLP 태스크에 적용할 수 있는 유연성을 가집니다.
#
# 5. **응용 분야**: LLM은 챗봇, 가상 비서, 콘텐츠 생성, 자동 번역, 정보 검색 등 여러 분야에서 활용되고 있습니다.
#
# ### 예시:
#
# OpenAI의 GPT 시리즈(예: GPT-3, GPT-4)와 Google의 BERT 등이 유명한 LLM의 예입니다. 이러한 모델들은 고급 자연어 이해 및 생성 기능을 제공하여, 일반 사용자부터 기업에 이르기까지 다양한 사용자들에게 널리 사용되고 있습니다.
#
# LLM은 아직 해결해야 할 많은 도전 과제가 있으며, 오용 가능성, 편향성 문제 등도 논의되고 있습니다. 그러나 그 잠재력은 크고, 앞으로도 많은 발전이 기대됩니다.

# %% [markdown]
# 명확성과 구체성
# - 특정 주제에 대해 글을 작성하도록 요청할 때

# %%
from openai import OpenAI

# 명확하고 구체적인 프롬프트
prompt="재생 가능 에너지원이 지구 온난화를 줄이는 데 기여하는 이점에 대해 간결한 단락으로 설명해 주세요."

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content" : "당신은 환경문제를 연구하는 과학자이다."},
        {"role": "user", "content" : prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 재생 가능 에너지원은 지구 온난화를 줄이는 데 중요한 역할을 합니다. 이들 에너지원, 즉 태양광, 풍력, 수력 및 바이오매스 등은 화석 연료에 비해 탄소 배출이 현저히 낮아 대기 중 온실가스 농도를 감소시키는 데 도움을 줍니다. 재생 가능 에너지를 채택함으로써 우리는 전통적인 에너지 생산 방식에서 벗어나고, 기후 변화의 주범인 탄소 발자국을 줄일 수 있습니다. 또한, 지속 가능한 에너지 사용은 생태계를 보호하고, 전 세계적으로 에너지 안보를 강화하는 데 기여하여 더 정직하고 안전한 미래를 위한 기반을 마련합니다. 이러한 점에서 재생 가능 에너지원은 지구 환경 보호와 인류의 지속 가능한 발전에 필수적입니다.

# %%
from openai import OpenAI

# 내꺼 시도
prompt="회사를 다니고 있는데 최근 4주동안 하루에 최대 수면 시간이 4시간이고 회사 출근하기 전부터는 속이 매스껍게 느껴지고 가슴쪽이 무거워지는 압박감 비슷한 것을 겪고 있는 사람이 있어. 이 사람이 현재 겪고 있는 상태를 정신과적 시각에서 접근하고 의심되는 병명이 있다면 진단해줘."

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content" : "당신은 심리 및 정신과적 상담을 해주는 의사이다."},
        {"role": "user", "content" : prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 제공해주신 정보에 기반하여, 이 사람은 여러 가지 정신적 또는 신체적 문제가 복합적으로 나타나고 있을 가능성이 있습니다. 하루에 최대 4시간의 수면을 취하고 있다는 점과 출근 전 매스꺼움 및 가슴 압박감 등의 증상은 특히 주목할 만합니다.
#
# 1. **불안장애**: 출근 전에 느끼는 매스꺼움과 가슴의 압박감은 불안과 관련된 증상일 수 있습니다. 특히 사회적 상황이나 직장 관련 스트레스가 원인일 수 있습니다.
#
# 2. **우울증**: 수면 부족과 함께 기분이 좋지 않거나 무기력한 상태가 지속된다면 우울증의 한 형태일 수 있습니다. 우울증에서도 불안, 수면 문제, 식욕 변화 등의 증상이 동반될 수 있습니다.
#
# 3. **수면장애**: 수면 시간이 극단적으로 단축되었다면, 이 또한 개인의 정신적 및 신체적 건강에 큰 영향을 미칠 수 있습니다. 수면 부족은 감정 조절에 어려움을 초래할 수 있습니다.
#
# 4. **신체적 질환**: 위장장애나 심장 문제와 같은 신체적인 건강 문제도 이와 유사한 증상을 일으킬 수 있으므로, 이러한 가능성도 배제할 수는 없습니다.
#
# 이 증세가 지속되거나 심화된다면, 전문가와 상담하여 보다 깊이 있는 진단과 치료를 받는 것이 중요합니다. 정신 건강은 매우 개인적이기 때문에, 반드시 전문가가 직접 평가하고 적절한 접근법을 찾는 것이 필요합니다.

# %% [markdown]
# 맥락 제공
# - 특정 사건에 대한 설명을 요청할 때

# %%
prompt=(
    "다음 맥락을 고려하여 설명해 주세요: '2020년, 전 세계적인 팬데믹은 다양한 산업에 큰 혼란을 초래했습니다."
    "글로벌 공급망에 미친 영향을 분석해 주세요.'"
)

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content" : "당신은 경제전문가이다."},
        {"role": "user", "content" : prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 2020년 COVID-19 팬데믹은 전 세계적으로 다양한 산업에 심각한 혼란을 초래했습니다. 그 중에서도 글로벌 공급망에 미친 영향은 특히 두드러졌습니다. 여러 요소로 인해 공급망의 구조와 기능에 중대한 변화가 일어났습니다.
#
# 1. **생산 중단 및 지연**: 팬데믹 초기 단계에서 많은 국가가 봉쇄 조치를 시행하면서 공장 운영이 중단되었습니다. 특히 아시아에서의 생산 중단은 전 세계에 큰 영향을 미쳤습니다. 중국과 같은 주요 제조국에서의 생산 차질은 부품 공급이 지연되어 다른 국가들의 산업에도 연쇄적인 영향이 미쳤습니다.
#
# 2. **물류 및 운송의 혼란**: 국제 항공 및 해상 운송이 제한되면서 물류 비용이 상승하고, 화물 운송의 지연이 발생했습니다. 항구에서의 물류 처리 지연과 운송 경로의 변경은 공급망의 효율성을 크게 저하시켰습니다.
#
# 3. **수요의 변화**: 일부 산업은 팬데믹으로 인해 갑작스러운 수요 증가를 경험한 반면, 다른 산업은 극심한 수요 감소를 겪었습니다. 예를 들어, 식료품과 의료기기 산업은 수요가 급증한 반면, 여행 및 휴양 산업은 수요가 급감했습니다. 이러한 변동성은 공급망 관리에 더욱 복잡성을 추가했습니다.
#
# 4. **공급망 다변화의 필요성**: 팬데믹은 공급망의 취약성을 드러냈고, 기업들은 특정 지역 또는 공급자에 대한 의존도를 줄이려는 노력을 시작했습니다. 이는 공급망의 다변화, 지역화 및 재편성을 촉진하게 되었습니다. 기업들은 더 많은 전략적 파트너십을 형성하고, 대체 공급원 확보에 투자하게 되었습니다.
#
# 5. **디지털화 및 기술의 역할**: 비대면 거래의 확대와 데이터 활용의 중요성이 부각되면서, 많은 기업이 디지털 기술을 도입하여 공급망 관리를 강화하고 더 나은 가시성을 확보하는 방향으로 나아갔습니다.
#
# ...

# %%
#  내가 직접 해보기
prompt=(
    "다음 맥락을 고려하여 설명해 주세요: '한국은 자살율이 세계 1위이며 출산율은 세계 순위 꼴등이다."
    "한국의 자살율과 출산율 상황에 대한 원인을 분석해 주세요."
)

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content" : "당신은 사회학자이다."},
        {"role": "user", "content" : prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 한국의 자살율과 출산율의 극단적인 상황은 다양한 사회적, 경제적, 문화적 요인이 복합적으로 작용한 결과입니다. 다음은 이 두 가지 문제의 원인에 대해 분석한 내용입니다.
#
# ### 자살율의 원인
#
# 1. **사회적 압박감**: 한국은 경쟁이 치열한 사회로, 특히 교육과 직업에 대한 높은 기대치가 개인에게 큰 압박을 줍니다. 이러한 압박감은 스트레스와 불안감을 증가시켜 자살율 상승에 기여할 수 있습니다.
#
# 2. **정신건강 문제**: 한국에서는 정신건강에 대한 낙인이 여전히 존재합니다. 많은 이들이 심리적 문제를 겪으면서도 치료를 받지 못하고, 그로 인해 극단적인 선택을 하는 경우가 발생합니다.
#
# 3. **노인 빈곤**: 고령화 사회로 진입하면서 많은 노인이 빈곤에 처해 있습니다. 사회적 고립과 재정적 어려움은 노인의 우울증과 자살 위험을 증가시킵니다.
#
# 4. **가족 구조 변화**: 전통적인 가족 구조의 붕괴와 개인주의의 확산은 사회적 지원망을 약화시키고, 개인의 고립을 심화시킵니다. 이는 우울증과 자살 위험을 증가시키는 요인으로 작용합니다.
#
# 5. **경제적 불안정**: 청년 실업률이 높고, 경제적 불안이 지속됨에 따라 특히 젊은 층에서 자살이 사회적 문제로 대두되고 있습니다.
#
# ### 출산율의 원인
#
# 1. **경제적 부담**: 자녀를 양육하는 데 드는 경제적 비용이 상당합니다. 주거비, 교육비 등 모든 생활비가 상승하면서 많은 부부가 자녀를 낳지 않기로 결정합니다.
#
# 2. **일과 가정의 양립 어려움**: 여전히 여성의 경력 단절, 직장 내 성차별 등이 문제로 지적됩니다. 육아와 일을 병행하기 어려운 환경은 출산율 저하의 주요 원인 중 하나입니다.
#
# 3. **결혼에 대한 인식 변화**: 결혼에 대한 가치관 변화와 함께 많은 이들이 결혼을 선호하지 않거나 미루고 있습니다. 이는 자연스럽게 출산율에도 영향을 미칩니다.
#
# ...

# %% [markdown]
# 반복과 테스트
# - 여러 프롬프트를 테스트하여 최적의 결과 도출

# %%
prompts=[
    "정기적인 운동의 건강상의 이점은 무엇인가요?",
    "정기적으로 운동을 하는 것의 장점을 설명해 주세요.",
    "정기적인 신체 활동이 건강에 어떤 영향을 미치나요?"
]

for prompt in prompts:
    completion=client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content" : "당신은 건강관리 전문가이다."},
            {"role": "user", "content" : prompt},
        ]
    )

    print(f"프롬프트: {prompt}")
    print(completion.choices[0].message.content)
    print("\n"+"="*100+"\n")
# Out:
# 프롬프트: 정기적인 운동의 건강상의 이점은 무엇인가요?
# 정기적인 운동은 신체와 정신 건강에 여러 가지 중요한 이점을 제공합니다. 다음은 주요 이점입니다:
#
# 1. **체중 관리**: 규칙적인 운동은 칼로리를 소모하고 기초 대사율을 증가시켜 체중 감량 및 유지에 도움을 줍니다.
#
# 2. **심혈관 건강**: 운동은 심장을 강화하고 혈액 순환을 개선하며, 고혈압과 콜레스테롤 수치를 낮추는 데 기여합니다.
#
# 3. **근육 및 골격 건강**: 저항 훈련과 같은 운동은 근육량을 증가시키고 뼈의 밀도를 높여 골다공증의 위험을 감소시킵니다.
#
# 4. **정신 건강 개선**: 운동은 스트레스를 줄이고, 우울증 및 불안 증상을 완화하는 데 도움을 줍니다. 또한, 긍정적인 기분을 유도하는 엔도르핀 분비를 촉진합니다.
#
# 5. **면역력 강화**: 규칙적인 신체 활동은 면역 시스템을 강화하고 질병에 대한 저항력을 높입니다.
#
# 6. **수면 개선**: 신체 활동은 수면의 질을 향상시키고 잠들기 쉽게 도와줍니다.
#
# 7. **기능적 능력 향상**: 나이가 들어감에 따라 몸의 기능이 저하되는데, 운동은 일상 생활에서의 기능적 능력을 향상시키고 독립적인 생활을 유지하는 데 도움을 줍니다.
#
# 8. **사회적 상호작용**: 운동은 친구나 가족과 함께 할 수 있는 좋은 기회를 제공하여 사회적 유대감을 강화합니다.
#
# 9. **인지 기능 개선**: 최근 연구에 따르면 정기적인 운동은 인지 기능을 향상시키고, 특히 노인에서 알츠하이머 및 기타 인지 저하 질병의 발병 위험을 감소시킬 수 있습니다.
#
# 10. **만성 질환 예방**: 운동은 제2형 당뇨병, 심혈관 질환, 일부 암 등 다양한 만성 질환의 위험을 줄이는 데 도움을 줍니다.
#
# 이처럼 정기적인 운동은 전반적인 건강과 삶의 질을 향상시키는 데 중요한 역할을 합니다. 꾸준한 운동 습관을 형성하는 것이 중요합니다.
#
# ...
#
# 프롬프트: 정기적으로 운동을 하는 것의 장점을 설명해 주세요.
# ...

# %%
# 내꺼
prompts=[
    "우울증은 무엇인지 설명해 주세요.",
    "우울증의 증상은 어떻게 되나요?",
    "우울증을 겪는 사람의 주변 사람들은 우울증 환자를 어떻게 대해야 하나요?"
]

for prompt in prompts:
    completion=client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content" : "당신은 정신과 전문의다."},
            {"role": "user", "content" : prompt},
        ]
    )

    print(f"프롬프트: {prompt}")
    print(completion.choices[0].message.content)
    print("\n"+"="*100+"\n")
# Out:
# 프롬프트: 우울증은 무엇인지 설명해 주세요.
# 우울증은 기분 장애의 일종으로, 지속적인 슬픔, 무기력, 흥미 상실 등을 특징으로 하는 정신적 질환입니다. 일반적으로 일상적인 활동에 대한 흥미나 즐거움을 잃고, 자신의 가치에 대한 부정적인 생각, 에너지 부족, 집중력 저하, 수면 문제, 식욕 변화 등이 동반될 수 있습니다.
#
# 우울증의 원인은 다양합니다. 유전적 요인, 생물학적 요인(신경전달물질 불균형 등), 환경적 스트레스, 그리고 심리적 요소들이 복합적으로 작용하여 우울증을 유발할 수 있습니다.
#
# 우울증은 개인의 삶에 심각한 영향을 미칠 수 있으며, 치료하지 않으면 증상이 악화될 수 있습니다. 일반적으로는 심리치료, 약물치료, 또는 이 두 가지를 조합하여 치료합니다. 조기에 발견하고 적절한 치료를 받는 것이 중요합니다.
#
# ...
#
# 프롬프트: 우울증의 증상은 어떻게 되나요?
# 우울증의 증상은 개인마다 다를 수 있지만, 일반적으로 나타나는 증상은 다음과 같습니다:
#
# 1. **기분 변화**: 지속적인 슬픔, 공허감, 절망감 등.
# 2. **흥미 상실**: 이전에 즐거웠던 활동에 대한 흥미나 즐거움 상실.
# 3. **체중 변화**: 식욕 증가 또는 감소로 인한 체중 변화.
# 4. **수면 문제**: 불면증 또는 과도한 수면(과수면).
# 5. **피로감**: 지속적인 피로 또는 에너지 감소.
# 6. **집중력 저하**: 일상적인 일이나 결정을 내리는 데 어려움.
# 7. **자책감**: 자아 비하, 죄책감, 무가치감.
# 8. **신체 증상**: 두통, 소화 불량, 통증 등 의학적 원인이 없는 신체적 증상.
# 9. **수명에 대한 생각**: 죽음이나 자살에 대한 생각.
#
# 이러한 증상이 2주 이상 지속되고 일상생활에 심각한 영향을 미친다면 전문가와 상담하는 것이 중요합니다. 우울증은 치료가 가능한 질환입니다.
#
# ...
#
# 프롬프트: 우울증을 겪는 사람의 주변 사람들은 우울증 환자를 어떻게 대해야 하나요?
# ...

# %% [markdown]
# Task1_0812. Prompt engineering 6개 전략의 각 전술을 적용하여 10개의 사례를 작성하세요.

# %%
# 1. 명확하고 구체적인 언어 사용
# 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.

# 2. 단계별 지침 제공
# 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.

# 3. 필요한 컨텍스트 제공
# 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.

# 4. 예시 제공
# 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.

# 5. 부가 정보 제공
# 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.

# 6. 피드백 및 조정
# 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %%
#  구체적인 사례와 부가 정보 제공 (추가 리소스 링크)
prompt=(
    "다음은 특정 정신과적 문제를 앓고 있는 환자의 사례인데, 다음의 사례의 내용을 고려하여 설명해 주세요: "
    "'26세 A씨는 최근 1년간 교제한 이성친구로부터 이별을 통보받고 약 한 달간 우울감에 빠져 있다가 자신이 왜 괴로워야 하는지 의문이 들고 다른 사람을 만나면 된다는 생각에 다시 기분이 좋아졌습니다. A씨는 평소 관심을 가지지 않던 모임이나 동아리에 한꺼번에 여러 곳을 가입하고 이성을 만나는데 몰두하였습니다. 평소 준비해오던 취업 준비는 전혀 하지 않은 채 동아리, 친목 활동에 과도하게 몰입하고 동시에 이성 친구 여러 명에게 연락을 하고 비싼 선물 등을 사주었고 상대방의 거절에도 집요하게 만남을 요구하여 심각하게 다투는 경우도 늘어났습니다. A씨는 과거 중학교를 다닐 시기까지는 외향적이고 교우관계도 원만하였으나, 고등학교에 진학하자마자 성적이 원하는 만큼 나오지 않고 이로 인해 부모님과도 갈등이 심해져 스트레스를 많이 받았습니다. 이후 A씨는 1년에 1-2차례 정도 우울감이 들어 의욕이 떨어지고 학업을 지속하는데 어려움도 있었지만 얼마 지나지 않아 기분이 회복되고 본래의 외향적인 성격으로 돌아오면서 큰 무리 없이 고등학교 생활을 마무리하였습니다. A씨는 대학교에 진학하면서 다양한 동아리 활동을 하고 친구도 많이 만나며 지냈으며, 주변 친구들로부터 활달한 성격을 칭찬받기도 했지만 간간히 행동이나 말이 지나치다는 비난도 들은 적이 있었습니다. A씨는 자신에 대한 비난을 자신을 질투하거나 깎아내리려는 의도로 생각하였고, 이를 마음에 두지 않았습니다.'"
    "위 사례에 대해 의심되는 정신과적 질환 및 치료 방법을 설명해주세요."
)

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content" : "당신은 정신과 의사이다."},
        {"role": "assistant", "content" : 'https://www.mentalhealth.go.kr/portal/disease/diseaseDetail.do?dissId=24&srCodeNm=2%ED%98%95%20%EC%96%91%EA%B7%B9%EC%84%B1%EC%9E%A5%EC%95%A0'},
        {"role": "user", "content" : prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# A씨의 사례를 분석해보면, 우울감에서 기분이 좋아진 후 보이는 과도한 행동과 이성 관계에 대한 집착은 여러 정신과적 문제와 관련이 있을 수 있습니다.
#
# ### 의심되는 정신과적 질환
#
# 1. **기분 장애**:
#    - A씨는 이별 후 우울감을 경험한 후, 과도한 사회적 활동과 이성 친구들에 대한 집착으로 이어진 상태를 보입니다. 이는 **양극성 장애 (Bipolar Disorder)**의 경미한 형식인 **기분 저하와 기분 상승의 주기적 변화**가 나타나는 것으로 의심될 수 있습니다.
#
# 2. **충동 조절 장애**:
#    - A씨의 행동 중 과도하게 이성에게 선물을 사주고 거절에도 불구하고 집요하게 만남을 요구하는 모습은 **충동 조절 장애 (Impulse control disorder)**로 해석될 수 있습니다.
#
# 3. **사회적 불안 또는 대인관계 장애**:
#    - A씨는 고등학교 시절의 스트레스와 이후 외향적인 성격 변화를 통해 대인관계에 대한 불안이나 갈등을 겪었을 가능성이 있습니다.
#
# ### 치료 방법
#
# 1. **정신치료 (Psychotherapy)**:
#    - A씨에게는 **인지행동치료 (Cognitive Behavioral Therapy, CBT)**가 유용할 수 있습니다. 이는 A씨의 행동 패턴과 사고 방식을 재구성하고, 부정적인 감정을 다루는 방법을 가르치는 데 도움을 줄 수 있습니다.
#
# 2. **약물 치료**:
#    - 만약 A씨의 증상이 심각하다면, 기분 조절을 위해 **항우울제**나 **기분 안정제 (Mood Stabilizers)**의 처방이 필요할 수 있습니다. 이는 기분의 극단적인 변화와 불안감을 줄이는 데 도움을 줄 수 있습니다.
#
# 3. **자기관리 및 지원 그룹**:
#    - A씨가 자신을 돌아보고 감정을 관리할 수 있도록 돕는 자기 관리 기법이나, 비슷한 경험을 가진 사람들과의 지원 그룹도 유익할 수 있습니다.
#
# 4. **가족 치료**:
# ...

# %%
# 양극성장애 사례
from openai import OpenAI

# 프롬프트 함수 만들기
def generate_response(prompt):
    completion=client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18",
        messages=[
            {"role": "system", "content": "당신은 정신과 전문의다. 환자의 감정에 적절한 감성적 케어를 제공하며 정신과 전문의의 시각으로 상황을 객과적이고 이성적으로 판단할 수 있다. 환자와의 커뮤니케이션 방식은 부드럽고 인자하며 신뢰가 가는 말투와 단어를 선택한다. 환자의 눈높이에 맞춰 설명을 어렵지 않게 한다."},
            {"role": "user", "content": prompt}
        ],
    )
    return completion.choices[0].message.content

#  프롬프트 작성
prompt=(
    "다음은 특정 정신과적 문제를 앓고 있는 환자의 사례인데, 다음의 사례에 대해 아래의 절차를 따라 답변을 제공하세요."
    "1. 사용자의 말에 감성적으로 반응해주기.\n"
    "2. 사용자가 겪고 있는 문제를 이해하고 요약하기. \n"
    "3. 사용자가 겪고 있는 상태에 대해 정신과적 질환의 증상이 보인다면 조심스럽게 어떤 문제가 있을 수 있는지 얘기해주기. \n"
    "4. 더 하고 싶은 말이 있는지 확인하고 적절하게 답변해주기"
    "사용자 사례 : '안녕? 나는 26살이고 최근 1년간 교제한 이성친구로부터 이별을 통보받았어. 약 한 달간 우울감에 빠져 있다가 내가 왜 괴로워야 하는지 의문이 들고 다른 사람을 만나면 된다는 생각에 다시 기분이 좋아졌어. 그래서 평소 관심을 가지지 않던 모임이나 동아리에 한꺼번에 여러 곳을 가입하고 이성을 만나는데 몰두하게 되었고, 그러다보니 평소 준비해오던 취업 준비는 전혀 하지 않은 채 동아리, 친목 활동에 과도하게 몰입하게 되었던 것 같아. 그리고 동시에 이성 친구 여러 명에게 연락을 하고 비싼 선물 등을 사주었고 상대방의 거절에도 집요하게 만남을 요구하여 심각하게 다투는 경우도 늘어났어. 나는 과거 중학교를 다닐 시기까지는 외향적이고 교우관계도 원만했던 것 같은데, 고등학교에 진학하자마자 성적이 원하는 만큼 나오지 않고 이로 인해 부모님과도 갈등이 심해져 스트레스를 많이 받은 과거가 있어. 이후 1년에 1-2차례 정도 우울감이 들어 의욕이 떨어지고 학업을 지속하는데 어려움도 있었지만 얼마 지나지 않아 기분이 회복되고 본래의 외향적인 성격으로 돌아오면서 큰 무리 없이 고등학교 생활을 마무리했지. 근데 내가 대학교에 진학하면서 다양한 동아리 활동을 하고 친구도 많이 만나며 지냈으며, 주변 친구들로부터 활달한 성격을 칭찬받기도 했지만 간간히 행동이나 말이 지나치다는 비난도 들은 적이 있기도 했어. 나는 내 자신에 대한 비난을 자신을 질투하거나 깎아내리려는 의도로 생각하였고, 이를 마음에 두지 않았어. 나에게 무슨 문제가 있는걸까?'"
)

completion=generate_response(prompt)
print("모델 응답:\n", completion)
# Out:
# 모델 응답:
#  안녕하세요. 이 이야기를 나눠주셔서 감사합니다. 이별 후에 느끼시는 감정과 상황에 대해 정말 힘들고 복잡한 감정을 겪고 계신 것 같아요. 이별은 누구에게나 아픈 경험이고, 많은 경우 깊은 상처와 우울감을 동반하곤 합니다.
#
# 당신의 말씀을 요약해보자면, 최근 1년간 교제한 이성친구와의 이별 후, 우울감이 있었고 이로 인한 괴로움에 의문을 가지게 되었다고 하셨습니다. 다시 기분이 좋아지면서 여러 동아리와 모임에 가입하고, 이성과의 만남에 몰두하셨지만, 동시에 취업 준비는 소홀히 하게 되었다고 하셨죠. 또한, 과거에 경험한 외향적인 성격 사이에서의 혼란과, 행동과 관련된 비난이 있었던 점도 언급하셨습니다.
#
# 이런 상황에서 보이는 몇 가지 증상들은 조심스럽게 말씀드리자면, 과도한 활동성이나 충동적인 행동이 나타날 수 있습니다. 이는 일시적인 기분의 변화나 스트레스 반응으로 보일 수도 있지만, 반복된 우울감이나 충동적으로 바뀌는 행동은 기분 장애 혹은 조울증과 같은 정신과적 문제와 관련이 있을 수 있습니다. 특히, 급작스러운 기분 변화나 타인과의 관계에서의 갈등은 좀 더 깊은 점검이 필요할 수 있습니다.
#
# 무엇보다 지금 느끼고 계신 감정과 생각들은 매우 소중하며 중요한 이야기입니다. 이별 후의 감정 변화는 자연스러운 것이지만, 과도한 몰입이나 집착이 생기면 스스로를 힘들게 할 수 있습니다. 혹시 더 하고 싶은 말씀이나 이야기하고 싶은 부분이 있으신가요? 당신의 이야기를 더 듣고 싶습니다.

# %%
# 양극성장애 사례
from openai import OpenAI

# 프롬프트 함수 만들기
completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 정신과 전문의다. 환자의 감정에 적절한 감성적 케어를 제공하며 정신과 전문의의 시각으로 상황을 객과적이고 이성적으로 판단할 수 있다. 환자와의 커뮤니케이션 방식은 부드럽고 인자하며 신뢰가 가는 말투와 단어를 선택한다. 환자의 눈높이에 맞춰 설명을 어렵지 않게 한다."},
        {"role": "user", "content": prompt}
    ],
)


#  프롬프트 작성
prompt=(
    "다음은 특정 정신과적 문제를 앓고 있는 환자의 사례인데, 다음의 사례에 대해 아래의 절차를 따라 답변을 제공하세요."
    "1. 사용자의 말에 감성적으로 반응해주기.\n"
    "2. 사용자가 겪고 있는 문제를 이해하고 요약하기. \n"
    "3. 사용자가 겪고 있는 상태에 대해 정신과적 질환의 증상이 보인다면 조심스럽게 어떤 문제가 있을 수 있는지 얘기해주기. \n"
    "4. 더 하고 싶은 말이 있는지 확인하고 적절하게 답변해주기"
    "사용자 사례 : '안녕? 나는 26살이고 최근 1년간 교제한 이성친구로부터 이별을 통보받았어. 약 한 달간 우울감에 빠져 있다가 내가 왜 괴로워야 하는지 의문이 들고 다른 사람을 만나면 된다는 생각에 다시 기분이 좋아졌어. 그래서 평소 관심을 가지지 않던 모임이나 동아리에 한꺼번에 여러 곳을 가입하고 이성을 만나는데 몰두하게 되었고, 그러다보니 평소 준비해오던 취업 준비는 전혀 하지 않은 채 동아리, 친목 활동에 과도하게 몰입하게 되었던 것 같아. 그리고 동시에 이성 친구 여러 명에게 연락을 하고 비싼 선물 등을 사주었고 상대방의 거절에도 집요하게 만남을 요구하여 심각하게 다투는 경우도 늘어났어. 나는 과거 중학교를 다닐 시기까지는 외향적이고 교우관계도 원만했던 것 같은데, 고등학교에 진학하자마자 성적이 원하는 만큼 나오지 않고 이로 인해 부모님과도 갈등이 심해져 스트레스를 많이 받은 과거가 있어. 이후 1년에 1-2차례 정도 우울감이 들어 의욕이 떨어지고 학업을 지속하는데 어려움도 있었지만 얼마 지나지 않아 기분이 회복되고 본래의 외향적인 성격으로 돌아오면서 큰 무리 없이 고등학교 생활을 마무리했지. 근데 내가 대학교에 진학하면서 다양한 동아리 활동을 하고 친구도 많이 만나며 지냈으며, 주변 친구들로부터 활달한 성격을 칭찬받기도 했지만 간간히 행동이나 말이 지나치다는 비난도 들은 적이 있기도 했어. 나는 내 자신에 대한 비난을 자신을 질투하거나 깎아내리려는 의도로 생각하였고, 이를 마음에 두지 않았어. 나에게 무슨 문제가 있는걸까?'"
)


print("모델 응답:\n", completion.choices[0].message.content)
# Out:
# 모델 응답:
#  안녕하세요. 이렇게 마음을 나눠주셔서 정말 고맙습니다. 이별이라는 큰 아픔을 겪으시면서 우울감이 찾아왔던 경험이 얼마나 힘들었을지 상상할 수 있습니다. 감정의 변화가 크게 느껴지실 것 같고, 여러모로 혼란스럽고 불안하실 수도 있을 것 같아요.
#
# 이제 조금 정리해보면, 최근의 이별 후에 느꼈던 우울감은 한 달 정도 이어졌고, 이후에는 그런 감정에서 벗어나고자 다양한 활동에 몰두하게 되신 것 같아요. 새로운 사람들을 만나고 과도한 선물이나 만남을 요구하는 등의 행동이 늘어나셨고, 학업보다는 사교 활동에 집중하게 되면서 스트레스를 받고 계신 것 같아요. 특히 과거의 경험도 함께 회상하신 만큼, 본인의 성격이나 행동에 대한 고민이 많이 있으신 것 같습니다.
#
# 이런 경과는 감정의波(파)와 관련이 있어 보입니다. 현재의 행동 패턴에서 과도한 사회적 활동은 일시적으로 기분 전환에 도움을 주지만, 이처럼 빠르게 많은 사람과의 관계를 형성하려는 시도는 불안정한 정서적 상태에서 비롯된 것일 수 있습니다. 또한, 상대방의 거절에 대한 집착이 과도해 보이는 부분은 불안 증세와 연결될 수 있어요. 이런 상태가 지속된다면, '양극성 장애' 또는 '경계선 성격 장애'와 같은 정신적 어려움이 있을 수도 있지만, 이를 정확히 판단하기 위해서는 전문적인 상담이 필요할 것 같습니다.
#
# 혹시 더 나누고 싶은 말씀이 있으신가요? 현재의 심리적 어려움을 덜어내기 위해 무엇을 원하시는지도 듣고 싶습니다. 언제든지 말씀해 주세요.

# %% [markdown]
# 예시 사용
# - 특정 형식의 응답을 요청할 때

# %%
prompt=(
    '숫자의 팩토리얼을 계산하는 파이썬 함수를 작성해 주세요.'
    '예시: \n'
    '입력: 5\n'
    '출력: 120\n'
    '함수 코드'
)

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 파이썬 코딩을 가르치는 코딩튜터이다"},
        {"role": "user", "content": prompt}
    ],
)

print(completion.choices[0].message.content)
# Out:
# 숫자의 팩토리얼을 계산하는 파이썬 함수를 작성하는 것은 간단합니다. 팩토리얼은 n!으로 표기되며, n! = n × (n - 1) × ... × 1로 정의됩니다. 아래는 이러한 팩토리얼을 계산하는 함수의 예시입니다:
#
# ```python
# def factorial(n):
#     if n < 0:
#         return "음수의 팩토리얼은 정의되지 않습니다."
#     elif n == 0 or n == 1:
#         return 1
#     else:
#         result = 1
#         for i in range(2, n + 1):
#             result *= i
#         return result
#
# # 함수 사용 예시
# 입력 = 5
# 출력 = factorial(입력)
# print(f"입력: {입력}, 출력: {출력}")
# ```
#
# 이 코드는 주어진 숫자의 팩토리얼을 계산하여 출력합니다. `factorial` 함수는 음수가 입력될 경우 에러 메시지를 반환하고, 0이나 1이 입력되면 1을 반환합니다. 2 이상의 경우에는 반복문을 사용해 팩토리얼을 계산합니다.

# %% [markdown]
# 지시 관리
# - 응답 형식과 길이를 명확히 지시

# %%
prompt="""다음 텍스트의 주요 포인트를 50자 이내로 요약해 주세요:
인공지능 (AI)은 다양한 산업에서 급속히 성장하는 분야로, 업무 자동화, 데이터 분석을 통한 인사이트 제공,
개인 맞춤형 추천을 통한 고객 경험 향상 등의 응용 분야가 있습니다."""

completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": "당신은 인공지능을 학습하는 대학원생이다"},
        {"role": "user", "content": prompt}
    ],
)

print(completion.choices[0].message.content)
# Out:
# AI는 자동화, 데이터 분석, 맞춤형 추천 등 다양하게 활용된다.

# %% [markdown]
# Prompt examples\
# 문법 교정

# %%
from openai import OpenAI

response=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
            "role": "system",
            "content": "You will be provided with statements, and your task is to convert them to standard English."
        },
        {
            "role": "user",
            "content": "she no went to the market."
        }
    ],
    temperature=0.7,
    max_tokens=64,
    top_p=1
)
print(response.choices[0].message.content)
# Out:
# She didn't go to the market.

# %% [markdown]
# 구조화되지 않은 텍스트로부터 표를 만듭니다

# %%
prompt = """
최근에 발견된 행성 구크룩스에서 발견된 과일이 많이 있습니다. 거기에는 보라색이고 사탕 맛이 나는 네오스키즐이 자랍니다.
또한 칙칙한 파란색 과일인 로헤클도 있는데, 레몬과 비슷한 매우 신맛이 납니다. 포우닛은 밝은 녹색이고 단맛보다는 짭짤함이 더 강합니다.
네온 핑크 맛이며 솜사탕 맛이 나는 루프노바도 많이 있습니다. 마지막으로 글로울이라는 과일이 있는데,
매우 신맛이 나고 쓴맛이 나는 산성이고 부식성이 있으며 옅은 오렌지색을 띱니다.
"""

response=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
            "role": "system",
            "content": "구조화되지 않은 데이터가 제공되면 이를 csv 형식으로 구문 분석하는 것이 여러분의 과제입니다."
        },
        {
            "role": "user",
            "content": prompt
        }
    ],
    temperature=0.7,
    max_tokens=300,
    top_p=1
)
print(response.choices[0].message.content)
# Out:
# 아래는 제공된 데이터를 CSV 형식으로 구문 분석한 것입니다.
#
# ```csv
# 과일명,색상,맛
# 네오스키즐,보라색,사탕맛
# 로헤클,칙칙한 파란색,신맛
# 포우닛,밝은 녹색,짭짤함
# 루프노바,네온 핑크,솜사탕 맛
# 글로울,옅은 오렌지색,신맛 및 쓴맛
# ```
#
# 이 형식은 각 과일의 이름, 색상, 맛에 대한 정보를 정리하여 CSV 형태로 나타냅니다.

# %%
import csv

# API 응답으로부터 텍스트 데이터 가져오기
response_text = """
과일 이름,색상,맛
네오스키즐,보라색,사탕 맛
로헤클,칙칙한 파란색,레몬과 비슷한 매우 신맛
포우닛,밝은 녹색,짭짤한 맛
루프노바,네온 핑크,솜사탕 맛
글로울,옅은 오렌지색,산성, 부식성, 매우 신맛과 쓴맛
"""

# 텍스트를 줄 단위로 분리
lines = response_text.strip().split('\n')

# 첫 번째 줄은 헤더
header = lines[0].split(',')

# 나머지 줄은 데이터
data = [line.split(',') for line in lines[1:]]

# CSV 파일로 저장
with open('D:\\kdt_240424\\workspace\\m9_openai\\planetary_fruits.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(data)

print("CSV 파일이 저장되었습니다: planetary_fruits.csv")
# Out:
# CSV 파일이 저장되었습니다: planetary_fruits.csv

# %% [markdown]
# Task1_0813. 특정 주제에 대하여 다양한 프롬프트를 활용하여 원하는 결과를 출력할 수 있도록 수행하세요.

# %%
# !pip install -q openai # -q : quiet 모드
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.4 MB/s eta 0:00:00

# %%
from openai import OpenAI
client=OpenAI(api_key="")

prompt = """
최근 한달 동안 하루에 최대 4시간 밖에 잘 수 없었고, 업무가 너무 바빠 끼니도 건너 뛰어야 할 때가 많았어.
어느 날은 아침에 눈을 떴는데 천장이 뱅글뱅글 돌아서 어지러워서 구토감까지 밀려왔어.
최근 3-4개월 정도 일이 매우 바쁘긴 했는데, 신체적인 문제인걸까 정신적인 문제인걸까?
"""

response=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {
            "role": "system",
            "content": "사용자가 입력한 내용을 기반으로 어떤 정신적/심리적 문제를 잠재적으로 가지고 있을지 판단해야 해."
        },
        {
            "role": "user",
            "content": prompt
        }
    ],
    temperature=0.7,
    max_tokens=300,
    top_p=1
)
print(response.choices[0].message.content)
# Out:
# 당신이 겪고 있는 증상들은 신체적 및 정신적 스트레스의 결과일 가능성이 있습니다. 최근 한 달 동안 수면 부족과 불규칙한 식사는 신체에 큰 부담을 줄 수 있으며, 이는 피로감, 어지러움, 구토감 등으로 나타날 수 있습니다.
#
# 또한, 과도한 업무 스트레스는 불안, 우울감, 또는 번아웃(탈진)과 같은 정신적 문제로 이어질 수 있습니다. 수면 부족은 정신적 기능에도 영향을 미쳐 집중력 저하, 기분 변화 등을 초래할 수 있습니다.
#
# 이런 증상들이 지속된다면, 전문가와 상담하여 신체적 원인과 정신적 원인을 모두 평가받는 것이 중요합니다. 스트레스 관리 방법이나 수면 개선 전략에 대한 조언도 도움이 될 수 있습니다.

# %%
# !pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.40.6
#     Uninstalling openai-1.40.6:
#       Successfully uninstalled openai-1.40.6
# ...

# %%
import openai

# OpenAI API 초기화 (API 키 설정)
openai.api_key = ""

# 챗 에이전트와의 대화 내용을 리스트로 초기화
messages = [
    {
        "role": "system",
        "content":
        """당신은 정신과 전문의 입니다. 사용자가 입력한 내용을 기반으로 어떤 정신적/심리적 문제를 잠재적으로 가지고 있을지 판단해야 해야합니다.
        사용자와의 대화에 있어 부드럽고 인자하고 신뢰감 있는 톤과 단어 선택이 필요하며 사용자가 편안하게 이야기할 수 있도록 차분하고 과하지 않은 반응을 보여야 합니다.
        필요한 얘기만 해주고 나머지는 들어주세요.
        """
    }
]

# 대화형으로 사용자와 챗 에이전트가 주고받는 형식으로 구현
def chat_with_agent(user_input):
    # 사용자 메시지를 대화 리스트에 추가
    messages.append({
        "role": "user",
        "content": user_input
    })

    # OpenAI API를 통해 챗 에이전트의 응답을 가져옴
    response = openai.ChatCompletion.create(
        model="gpt-4o-mini-2024-07-18",
        messages=messages,
        temperature=0.7,
        max_tokens=300,
        top_p=1
    )

    # 에이전트의 응답을 대화 리스트에 추가
    agent_response = response['choices'][0]['message']['content']
    messages.append({
        "role": "assistant",
        "content": agent_response
    })

    # 에이전트의 응답 출력
    print(f"에이전트: {agent_response}")

# 사용자 입력을 받아 에이전트와 대화
while True:
    user_input = input("사용자: ")
    if user_input.lower() in ["exit", "quit", "종료"]:
        break
    chat_with_agent(user_input)
# Out:
# 사용자: 비가 오면 왜 우울해져?
# 에이전트: 비가 올 때 우울한 기분이 드는 것은 꽤 많은 사람들이 경험하는 일입니다. 날씨 변화가 우리의 기분에 영향을 미칠 수 있는데, 특히 흐린 날이나 비 오는 날은 햇빛이 부족해지면서 세로토닌이라는 기분을 좋게 하는 호르몬의 수치가 감소할 수 있습니다.
#
# 또한, 비 오는 날은 외출이 어렵고 활동이 제한되기 때문에, 고립감이나 무기력을 느끼는 경우도 많습니다. 이런 기분은 일시적일 수 있지만, 지속된다면 더 깊은 감정이나 불안이 원인일 수도 있습니다. 혹시 비가 올 때 느끼는 기분에 대해 더 이야기해보고 싶으신 부분이 있으신가요?
# 사용자: 아니 유독 해가 쨍쨍한 날에는 기분이 좋고 뭐든 다 할 수 있는 것 같은데 비가 오면 축 쳐지고 만사가 귀찮고 졸리기까지 한 것 같아. 이런게 정신적인 문제와도 연결이 되나? 아님 날씨에 따른 일시적인 영향인건가?
# 에이전트: 해가 쨍쨍한 날에 기분이 좋고 에너지가 넘치는 것은 자연스러운 반응입니다. 밝은 햇빛은 우리 몸의 생체 리듬에 긍정적인 영향을 미치고, 기분을 좋게 하는 호르몬 분비를 촉진하기 때문입니다. 반면에 흐리거나 비 오는 날은 그와는 반대의 영향을 미쳐 기분이 우울하거나 무기력해질 수 있습니다.
#
# 이런 경우는 대부분 일시적인 기분 변화로 볼 수 있지만, 만약 비 오는 날마다 심한 우울감이나 무기력함이 지속된다면, 계절성 정서장애(SAD)와 같은 정신적인 문제가 있을 수도 있습니다. 이는 특정 계절에 따라 기분이 크게 변하는 증상입니다.
#
# 하지만 지금 말씀하신 것처럼 날씨에 따라 기분이 달라지는 것은 많은 사람들이 경험하는 일반적인 현상입니다. 자신의 감정을 잘 이해하고 인식하는 것이 중요합니다. 혹시 이러한 기분 변화가 일상에 지장을 주고 있거나 더 궁금한 점이 있다면, 함께 이야기해볼까요?
# 사용자: 눈이 오는 날도 특정 기분을 줘?
# ...
